# %% [markdown]
# # HISTORY
#
# #### New Hycean Planets, Near K2-18 - b
#
# * The star has an exoplanet, called K2-18b, a super-Earth located within the habitable zone of K2-18. It is the first exoplanet in the habitable zone, albeit a gas giant, to have water discovered in its atmosphere. The star also has a second planet K2-18c, which is proven by system tidal simulation to be a small gas giant
#
# * K2-18b, also known as EPIC 201912552 b, is an exoplanet orbiting the red dwarf K2-18, located 124 light-years (38 pc) away from Earth. The planet, initially discovered with the Kepler space telescope, is about eight times the mass of Earth, and is thus classified as a super Earth. It has a 33-day orbit within the star's habitable zone.
#
# * In September 2019, two independent research studies, combining data from the Kepler space telescope, the Spitzer Space Telescope, and the Hubble Space Telescope, concluded that there are significant amounts of water vapor in its atmosphere, a first for an exoplanet in the habitable zone.
#
# * A new class of 'waterworld' exoplanets have been found by astronomers, who say that despite being hot, ocean-covered and hydrogen-rich - could support life.
#
# * They have been dubbed 'Hycean' world's by the team from the University of Cambridge, who say they 'greatly increase our chance of finding alien life.'
#
# * In the search for life elsewhere, researchers have mostly looked for planets of a similar size, mass, temperature and atmospheric composition to Earth.
#
# * Astronomers now say there may be more promising candidates out there, and these Hycean worlds are more numerous than Earth-like planets.
#
# * The habitable exoplanets are hot, ocean-covered worlds with hydrogen-rich atmospheres, and are more observable than Earth-like planets due to their temperature, making them easier to detect with current telescopes.
#
# * Dr Nikku Madhusudhan from Cambridge's Institute of Astronomy, who led the research, said they open a whole new avenue of search for life elsewhere.
#
# * Many of the prime candidates of these planets identified by the researchers are bigger and hotter than Earth.
#
# * This data includes FITS files of previously discovered habitats. It will be used for research.

# %% [markdown]
# # K2-18b
#
# * Discovery date
#
# 2015
#
# * Detection method
#
# Transit
#
# * Semi-major axis
#
# 0.1429 (+0.0060−0.0065) AU
#
# 21,380,000 km
#
# * Eccentricity
#
# 0.20 (±0.08)
#
# * Orbital period
#
# 32.939623 (+0.000095−0.000100) d
#
# * Inclination
#
# 89.5785° (+0.0079°−0.0088°)
#
# * Argument of periastron
#
# −0.10 (+0.81−0.59) rad
#
#
# * Semi-amplitude
#
# 3.55 (+0.57−0.58) m/s
#
#
# * Mean radius
#
# 2.610 (±0.087) R⊕
#
# * Mass
#
# 8.63 (±1.35) M⊕
#
# * Mean density
#
# 4.01 g/cm3
#
# * Surface gravity
#
# ≤1.66 g
#
# * Temperature
#
# 265 ± (5 K) (−8 ± 5 °C)

# %% [markdown]
# # MATH SHEET
#
# #### FUNDAMENTAL UNIT OF DISTANCE IN ASTRONOMY
#
# "A star with a parallax of 1 arcsecond has a distance of 1 Parsec."
#
# * 1 parsec (pc) is equivalent to:
#
# 206,265 AU
#
# 3.26 Light Years
#
# 3.086x1013 km
#
# * 1 light year (ly) is equivalent to:
#
# 0.31 pc
#
# 63,270 AU
#
# #### GENERAL CONSTANTS
#
# * Speed of Light = c = 3 ˆ 108 m/s
# * Gravitational Constant = G = 6.67 * 10 ** -11N m2/kg2
# * Mass of Earth = MC = 5.97 * 10 ** 24 kg
# * Radius of Earth = RC = 6378 km
# * Mass of the sun = M@ = 1.99 * 10 ** 30 kg
# * Radius of the sun = R@ = 6.96 * 10 ** 5 km
# * Effective Temperature of the sun = T@ = 5778 K
# * Luminosity of the sun = L@ = 3.9 * 10 ** 26W
# * Mass of the Moon = MK = 7.346 * 10 ** 22 kg
# * Radius of the Moon = RK = 1738.1 km
# * Mass of a proton = mp = 1.6726 * 10 ** -27 kg
# * Mass of an Electron = me = 9.109 * 10 ** -31 kg
# * Hubble’s Constant = H0 = 70 km/s/Mpc (Note: There is ongoing debate about the actual value)
# * Planck’s Constant = h = 6.626 * 10 ** -34 J s
# * Type Ia Supernova Absolute Magnitude = -19.3
#
# #### GENERAL CONVERSIONS
#
# * 1 Astronomical Unit = 1 AU = 1.5 * 10 ** 8 km
# * 1 Parsec = 1 pc = 3.09 * 10 ** 13km = 3.26 ly
# * 1 Light Year = 1 ly = 9.46 * 10 ** 12 km
# * 1 Mega Light Year (Mly) = 10 ** 6 Light Year - 306,601 parsecs - 9.4607304725808 × 1018 km
# * Arc Minute = 11 = p
# * 1 year = 31.557.600 seconds
# * 1 Megaton (energy) = 1.000.000 tons of TNT = 4.184 * 10 ** 15 J
# * MPC = MEGAPARSEC (A megaparsec is a measurement of distance equal to one million parsecs or 3.26 million light years)
#
# #### LIGHT INTENSITY
#
# * LI = 1 / DISTANCE FROM EARTH ** 2
#
# #### VACUUM FREQUENCY
#
# f = c/λ
#
# * f = Wave frequency (Hz)
# * c = Speed of Light (m/s)
# * λ = wavelength (m)
#
# #### ORBIT ECCENTRICITY
#
# e = c/a
#
# * e = Orbital Eccentricity
# * c = Distance from focus to center
# * a = semimajor axis
#
# #### PARALLAX
#
# d = 1/p
#
# * d = Distance (pc)
# * p = Parallax Angle (arcseconds)
#
# https://lco.global/spacebook/sky/using-angles-describe-positions-and-apparent-sizes-objects/
#
# #### HUBBLE'S LAW
#
# v = H0 . d
#
# * v = Recessional velocity (km/s)
# * H0 = Hubble’s Constant
# * d = Distance
#
# #### WHAT IS TRANSIT DETECTION
#
# * The transit method is a photometric method that aims to indirectly detect the presence of one or more exoplanets in orbit around a star. In 1999, the method was used to confirm the existence of HD209458b, a planet that had been discovered almost at the same time by the radial velocity method. This discovery, published in 2000 in a study led by David Charbonneau, among others, was made using a 10-cm diameter telescope installed in the parking lot of a building in the United States and paved the way for a whole new field of research on exoplanets. The first new detection was OGLE-TR-56b, discovered in 2003.
#
# ![](https://i2.wp.com/www.exoplanetes.umontreal.ca/wp-content/uploads/2020/02/transit2.png?resize=768%2C458)
#
# * The transit method consists of regularly measuring the luminosity of a star in order to detect the periodic decrease in luminosity associated with the transit of an exoplanet. The transit happen when a planet passes in front of its star. On the other hand, when the planet passes behing the star, it is called an eclipse. The effect measured during a transit is quite small. For a star the size of the Sun, the transit of a Jupiter-size planet will cause a decrease in apparent luminosity of about 1%, while this decrease will be of about 0.001% for a planet the size of the Earth.
#
# ![](https://planetary.s3.amazonaws.com/web/assets/pictures/_1200x716_crop_center-center_82_line/20130108_Planetary_transit.jpg.webp)
#
# * How much a star dims during a transit directly relates to the relative sizes of the star and the planet. A small planet transiting a large star will create only a slight dimming, while a large planet transiting a small star will have a more noticeable effect. The size of the host star can be known with considerable accuracy from its spectrum, and photometry therefore gives astronomers a good estimate of the orbiting planet's diameter, but not its mass. This makes photometry an excellent complement to the radial-velocity method, which allows an estimate (a lower limit) of a planet's mass, but provides no information on the planet's diameter. Using both methods, combining mass and diameter, scientists can calculate the planet's density. Density, in turn, can suggest whether a planet is rocky, gassy, or in between.
#
# ![](https://planetary.s3.amazonaws.com/web/assets/pictures/_1200x581_crop_center-center_82_line/283591/20200424_TPS_20_01_Exoplanet-InfoSushi_Final_1920_Light-2.jpg.webp)
#
# * Transit photometry is currently the most effective and sensitive method for detecting extrasolar planets. It is a particularly advantageous method for space-based observatories that can stare continuously at stars for weeks or months. It also can be performed from the ground with quite small telescopes; the TRAPPIST telescopes only have 60-centimeter primary mirrors.
#
# * Transits provide scientists with estimates of planet diameters, a physical property not otherwise measurable. Because transiting exoplanets orbit in orbital planes that are necessarily edge-on to Earth-based observers, using both the transit method and the radial-velocity method to observe the same planet can provide the planet's mass and therefore its density and likely composition. Transits can provide scientists with a great deal of infFirst and foremost the "dip" in a star's luminosity during transit is directly propotionate to the size of the planet. Since the star's size is known known with a high degree of accuracy, the planet's size can be deduced from the degree to which it dims during transit.
#
# * If the transiting planet has an atmosphere, some of the light from the star passes through the planet's atmosphere on its way to Earth. Some wavelengths of that starlight are preferentially blocked by gases in the atmosphere. By studying the spectrum of a star both during a transit and outside a transit, astronomers can find telltale dips in the spectrum of starlight that are diagnostic of the presence of atmospheric gases. Water vapor is one molecule that can be observed using transit spectroscopy.
#
# * Finally, transit photometry searches can operate on a massive scale. Transit surveys (both ground- and space-based) can simultaneously watch as many as 100,000 stars at a time.
#
# #### WHAT IS SEMI-AMPLITUDE
#
# * The astrometric amplitude of the wobble of a host star induced by its companion in au is derived straightforwardly from balance of the star/planet system about its center of mass. The distance to the system then determines the angular size of the projected motion on the sky.
#
# #### WHAT IS SURFACE GRAVITY
#
# * The surface gravity, g, of an astronomical object is the gravitational acceleration experienced at its surface at the equator, including the effects of rotation. The surface gravity may be thought of as the acceleration due to gravity experienced by a hypothetical test particle which is very close to the object's surface and which, in order not to disturb the system, has negligible mass. For objects where the surface is deep in the atmosphere and the radius not known, the surface gravity is given at the 1 bar pressure level in the atmosphere.
#
# * Surface gravity is measured in units of acceleration, which, in the SI system, are meters per second squared. It may also be expressed as a multiple of the Earth's standard surface gravity, g = 9.80665 m/s². In astrophysics, the surface gravity may be expressed as log g, which is obtained by first expressing the gravity in cgs units, where the unit of acceleration is centimeters per second squared, and then taking the base-10 logarithm. Therefore, the surface gravity of Earth could be expressed in cgs units as 980.665 cm/s², with a base-10 logarithm (log g) of 2.992.
#
# * The surface gravity of a white dwarf is very high, and of a neutron star even higher. A white dwarf's surface gravity is around 100,000g (9.84 ×105 m/s²) whilst the neutron star's compactness gives it a surface gravity of up to 7×1012 m/s² with typical values of order 1012 m/s² (that is more than 1011 times that of Earth). One measure of such immense gravity is that neutron stars have an escape velocity of around 100,000 km/s, about a third of the speed of light. For black holes, the surface gravity must be calculated relativistically.
#
#
# #### WHAT IS ORBITAL ECCENTRICITY
#
# * In astrodynamics, the orbital eccentricity of an astronomical object is a dimensionless parameter that determines the amount by which its orbit around another body deviates from a perfect circle. A value of 0 is a circular orbit, values between 0 and 1 form an elliptic orbit, 1 is a parabolic escape orbit, and greater than 1 is a hyperbola. The term derives its name from the parameters of conic sections, as every Kepler orbit is a conic section. It is normally used for the isolated two-body problem, but extensions exist for objects following a rosette orbit through the galaxy.

# %% [markdown]
# # PACKAGES AND LIBRARIES

# %%
# !pip install astropy
# !pip install specutils
# Out:
# ...
#      |████████████████████████████████| 10.7 MB 14.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 746 kB 51.9 MB/s eta 0:00:01
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...
#      |████████████████████████████████| 194 kB 13.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 401 kB 28.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 104 kB 26.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 109 kB 55.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 79 kB 8.2 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 68 kB 6.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 191 kB 56.1 MB/s eta 0:00:01
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 61 kB 5.9 MB/s  eta 0:00:01
# ...

# %%
#GENERAL

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as mtpltcm
from mpl_toolkits.mplot3d import Axes3D
import random
import time

#PATH PROCESS

import os
import os.path
from pathlib import Path
import glob
from scipy.io import loadmat
import nibabel as nib
import csv
from astropy.visualization import astropy_mpl_style
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits
import astropy
from astropy import units as u 
import astropy.wcs as fitswcs
from specutils import Spectrum1D, SpectralRegion
from astropy.cosmology import WMAP9 as Cosmology

#IMAGE PROCESS

from PIL import Image
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from keras.applications.vgg16 import preprocess_input, decode_predictions
from keras.preprocessing import image
from skimage.feature import hessian_matrix, hessian_matrix_eigvals
from scipy.ndimage.filters import convolve
from skimage import data, io, filters
import skimage.morphology as morph
import skimage.exposure as skie
import skimage
from skimage.morphology import convex_hull_image, erosion
from IPython import display
from scipy.ndimage import gaussian_filter
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import matplotlib.patches as patches

#SCALER & TRANSFORMATION

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import regularizers
from sklearn.preprocessing import LabelEncoder
import sklearn

import pydub
from scipy.io.wavfile import read, write
import librosa
import librosa.display
import IPython
from IPython.display import Audio
import scipy
from scipy import signal
from scipy.fft import fftshift

#IGNORING WARNINGS

from warnings import filterwarnings

filterwarnings("ignore",category=DeprecationWarning)
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)
filterwarnings("ignore", category=RuntimeWarning)
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# <ipython-input-3-e64bb677aea2> in <module>
#      26 from astropy import units as u
#      27 import astropy.wcs as fitswcs
# ---> 28 from specutils import Spectrum1D, SpectralRegion
#      29 from astropy.cosmology import WMAP9 as Cosmology
#      30
#
# /opt/conda/lib/python3.7/site-packages/specutils/__init__.py in <module>
#      15
#      16     # Allow loading spectrum object from top level module
# ---> 17     from .spectra import *  # noqa
#      18
#      19     # Load the IO functions
#
# /opt/conda/lib/python3.7/site-packages/specutils/spectra/__init__.py in <module>
#       3 `~astropy.nddata.NDData`-inherited classes used for storing the spectrum data.
#       4 """
# ----> 5 from .spectrum1d import *  # noqa
#       6 from .spectral_region import *  # noqa
#       7 from .spectrum_collection import *  # noqa
#
# ...

# %% [markdown]
# # OVERVIEW AND DATA ANALYSIS

# %% [markdown]
# ### K2-18 PATH

# %%
NEAR_INFRARED_K2_18 = "../input/k1218-red-dwarf-star-fits-data-nasa/NEAR_HYCEAN_PLANETS/K12_18/ico529i1q_drz.fits"
HST_OPTICAL_K2_18_ONE = "../input/k1218-red-dwarf-star-fits-data-nasa/NEAR_HYCEAN_PLANETS/K12_18/HST-OPTICAL/ocy711ikq_raw.fits"
HST_OPTICAL_K2_18_TWO = "../input/k1218-red-dwarf-star-fits-data-nasa/NEAR_HYCEAN_PLANETS/K12_18/HST-OPTICAL/ocy711ilq_raw.fits"
HST_OPTICAL_K2_18_THREE = "../input/k1218-red-dwarf-star-fits-data-nasa/NEAR_HYCEAN_PLANETS/K12_18/HST-OPTICAL/ocy721ajq_raw.fits"
HST_OPTICAL_K2_18_FOUR = "../input/k1218-red-dwarf-star-fits-data-nasa/NEAR_HYCEAN_PLANETS/K12_18/HST-OPTICAL/ocy721akq_raw.fits"

# %% [markdown]
# ### READING FITS FILE

# %%
OPEN_NI = fits.open(NEAR_INFRARED_K2_18)
OPEN_HST_ONE = fits.open(HST_OPTICAL_K2_18_ONE)
OPEN_HST_TWO = fits.open(HST_OPTICAL_K2_18_TWO)
OPEN_HST_THREE = fits.open(HST_OPTICAL_K2_18_THREE)
OPEN_HST_FOUR = fits.open(HST_OPTICAL_K2_18_FOUR)

# %%
FITS_OPEN_LIST = [OPEN_NI,OPEN_HST_ONE,OPEN_HST_TWO,OPEN_HST_THREE,OPEN_HST_FOUR]
FITS_NAME_LIST = ["NEAR_INFRARED","HST_ONE","HST_TWO","HST_THREE","HST_FOUR"]

# %% [markdown]
# ### INFORMATIONS

# %%
for x_fits_name,x_fits_file in zip(FITS_NAME_LIST,FITS_OPEN_LIST):
    print("\n")
    print(x_fits_name + "\n")
    print(x_fits_file.info())
    print("---"*10)
    print("\n")

# %% [markdown]
# ### GETTING COMMENTS FUNCTIONS

# %%
NEAR_INFRARED_FUNCTION_PRIMARY = OPEN_NI[0].header
NEAR_INFRARED_FUNCTION_SCI = OPEN_NI[1].header

HST_ONE_FUNCTION_PRIMARY = OPEN_HST_ONE[0].header
HST_ONE_FUNCTION_SCI = OPEN_HST_ONE[1].header

HST_TWO_FUNCTION_PRIMARY = OPEN_HST_TWO[0].header
HST_TWO_FUNCTION_SCI = OPEN_HST_TWO[1].header

HST_THREE_FUNCTION_PRIMARY = OPEN_HST_THREE[0].header
HST_THREE_FUNCTION_SCI = OPEN_HST_THREE[1].header

HST_FOUR_FUNCTION_PRIMARY = OPEN_HST_FOUR[0].header
HST_FOUR_FUNCTION_SCI = OPEN_HST_FOUR[1].header

# %% [markdown]
# ### GETTING KEYWORDS

# %%
NEAR_INFRARED_PRIMARY_KEYS = NEAR_INFRARED_FUNCTION_PRIMARY.keys()
NEAR_INFRARED_SCI_KEYS = NEAR_INFRARED_FUNCTION_SCI.keys()

HST_ONE_PRIMARY_KEYS = HST_ONE_FUNCTION_PRIMARY.keys()
HST_ONE_SCI_KEYS = HST_ONE_FUNCTION_SCI.keys()

HST_TWO_PRIMARY_KEYS = HST_TWO_FUNCTION_PRIMARY.keys()
HST_TWO_SCI_KEYS = HST_TWO_FUNCTION_SCI.keys()

HST_THREE_PRIMARY_KEYS = HST_THREE_FUNCTION_PRIMARY.keys()
HST_THREE_SCI_KEYS = HST_THREE_FUNCTION_SCI.keys()

HST_FOUR_PRIMARY_KEYS = HST_FOUR_FUNCTION_PRIMARY.keys()
HST_FOUR_SCI_KEYS = HST_FOUR_FUNCTION_SCI.keys()

# %% [markdown]
# # FULL HEADER READING

# %% [markdown]
# ### ATTENTION
# * RUN FOR CHECKING

# %% [markdown]
# ### PRIMARY

# %%
NEAR_INFRARED_FUNCTION_PRIMARY

# %%
HST_ONE_FUNCTION_PRIMARY

# %%
HST_TWO_FUNCTION_PRIMARY

# %%
HST_THREE_FUNCTION_PRIMARY

# %%
HST_FOUR_FUNCTION_PRIMARY

# %% [markdown]
# ### SCI

# %%
NEAR_INFRARED_FUNCTION_SCI

# %%
HST_ONE_FUNCTION_SCI

# %%
HST_TWO_FUNCTION_SCI

# %%
HST_THREE_FUNCTION_SCI

# %%
HST_FOUR_FUNCTION_SCI

# %% [markdown]
# # PLANETARY SCIENCE KEYWORDS

# %% [markdown]
# ### ATTENTION
# * RUN FOR CHECKING

# %% [markdown]
# ### NEAR INFRARED

# %% [markdown]
# #### TARGET INFORMATIONS

# %%
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["TARGNAME"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["RA_TARG"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["DEC_TARG"])

# %% [markdown]
# #### EXPOSURE INFORMATION

# %%
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["SUNANGLE"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["SUNANGLE"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["MOONANGL"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["MOONANGL"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["DATE-OBS"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["DATE-OBS"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["TIME-OBS"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["TIME-OBS"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["EXPSTART"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["EXPSTART"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["EXPEND"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["EXPEND"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["EXPTIME"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["EXPTIME"])

# %% [markdown]
# #### PHOTOMETRY KEYWORDS

# %%
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["PHOTFLAM"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_PRIMARY["PHOTFLAM"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["PHOTFNU"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_PRIMARY["PHOTFNU"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["PHOTZPT"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_PRIMARY["PHOTZPT"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["PHOTPLAM"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_PRIMARY["PHOTPLAM"])
print(NEAR_INFRARED_FUNCTION_PRIMARY.comments["PHOTBW"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_PRIMARY["PHOTBW"])

# %% [markdown]
# #### WORLD COORDINATE SYSTEM

# %%
print(NEAR_INFRARED_FUNCTION_SCI.comments["LTV1"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_SCI["LTV1"])
print(NEAR_INFRARED_FUNCTION_SCI.comments["LTV2"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_SCI["LTV2"])
print(NEAR_INFRARED_FUNCTION_SCI.comments["LTM1_1"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_SCI["LTM1_1"])
print(NEAR_INFRARED_FUNCTION_SCI.comments["LTM2_2"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_SCI["LTM2_2"])
print(NEAR_INFRARED_FUNCTION_SCI.comments["PA_APER"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_SCI["PA_APER"])
print(NEAR_INFRARED_FUNCTION_SCI.comments["RA_APER"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_SCI["RA_APER"])
print(NEAR_INFRARED_FUNCTION_SCI.comments["DEC_APER"] + " ","%.10f" % NEAR_INFRARED_FUNCTION_SCI["DEC_APER"])

# %% [markdown]
# ### HST OPTICAL ONE

# %% [markdown]
# #### TARGET INFORMATIONS

# %%
print(HST_ONE_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_ONE_FUNCTION_PRIMARY["TARGNAME"])
print(HST_ONE_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_ONE_FUNCTION_PRIMARY["RA_TARG"])
print(HST_ONE_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_ONE_FUNCTION_PRIMARY["DEC_TARG"])

# %% [markdown]
# #### WORLD COORDINATE SYSTEM

# %%
print(HST_ONE_FUNCTION_SCI.comments["LTV1"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["LTV1"])
print(HST_ONE_FUNCTION_SCI.comments["LTV2"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["LTV2"])
print(HST_ONE_FUNCTION_SCI.comments["LTM1_1"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["LTM1_1"])
print(HST_ONE_FUNCTION_SCI.comments["LTM2_2"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["LTM2_2"])
print(HST_ONE_FUNCTION_SCI.comments["RA_APER"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["RA_APER"])
print(HST_ONE_FUNCTION_SCI.comments["DEC_APER"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["DEC_APER"])
print(HST_ONE_FUNCTION_SCI.comments["PA_APER"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["PA_APER"])

# %% [markdown]
# #### EXPOSURE INFORMATION

# %%
print(HST_ONE_FUNCTION_SCI.comments["ORIENTAT"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["ORIENTAT"])
print(HST_ONE_FUNCTION_SCI.comments["SUNANGLE"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["SUNANGLE"])
print(HST_ONE_FUNCTION_SCI.comments["MOONANGL"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["MOONANGL"])
print(HST_ONE_FUNCTION_SCI.comments["SUN_ALT"] + " ","%.10f" % HST_ONE_FUNCTION_SCI["SUN_ALT"])
print(HST_ONE_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_ONE_FUNCTION_SCI["DATE-OBS"])
print(HST_ONE_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_ONE_FUNCTION_SCI["TIME-OBS"])

# %% [markdown]
# #### TARGET ACQUISITION PARAMETERS

# %%
print(HST_ONE_FUNCTION_SCI.comments["TARGA1"] + " ",HST_ONE_FUNCTION_SCI["TARGA1"])
print(HST_ONE_FUNCTION_SCI.comments["TARGA2"] + " ",HST_ONE_FUNCTION_SCI["TARGA2"])
print(HST_ONE_FUNCTION_SCI.comments["APERA1"] + " ",HST_ONE_FUNCTION_SCI["APERA1"])
print(HST_ONE_FUNCTION_SCI.comments["APERA2"] + " ",HST_ONE_FUNCTION_SCI["APERA2"])

# %% [markdown]
# ### HST OPTICAL TWO

# %% [markdown]
# #### TARGET INFORMATIONS

# %%
print(HST_TWO_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_TWO_FUNCTION_PRIMARY["TARGNAME"])
print(HST_TWO_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_TWO_FUNCTION_PRIMARY["RA_TARG"])
print(HST_TWO_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_TWO_FUNCTION_PRIMARY["DEC_TARG"])

# %% [markdown]
# #### WORLD COORDINATE SYSTEM

# %%
print(HST_TWO_FUNCTION_SCI.comments["LTV1"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["LTV1"])
print(HST_TWO_FUNCTION_SCI.comments["LTV2"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["LTV2"])
print(HST_TWO_FUNCTION_SCI.comments["LTM1_1"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["LTM1_1"])
print(HST_TWO_FUNCTION_SCI.comments["LTM2_2"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["LTM2_2"])
print(HST_TWO_FUNCTION_SCI.comments["RA_APER"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["RA_APER"])
print(HST_TWO_FUNCTION_SCI.comments["DEC_APER"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["DEC_APER"])
print(HST_TWO_FUNCTION_SCI.comments["PA_APER"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["PA_APER"])

# %% [markdown]
# #### EXPOSURE INFORMATION

# %%
print(HST_TWO_FUNCTION_SCI.comments["ORIENTAT"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["ORIENTAT"])
print(HST_TWO_FUNCTION_SCI.comments["SUNANGLE"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["SUNANGLE"])
print(HST_TWO_FUNCTION_SCI.comments["MOONANGL"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["MOONANGL"])
print(HST_TWO_FUNCTION_SCI.comments["SUN_ALT"] + " ","%.10f" % HST_TWO_FUNCTION_SCI["SUN_ALT"])
print(HST_TWO_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_TWO_FUNCTION_SCI["DATE-OBS"])
print(HST_TWO_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_TWO_FUNCTION_SCI["TIME-OBS"])

# %% [markdown]
# ### HST OPTICAL THREE

# %% [markdown]
# #### TARGET INFORMATIONS

# %%
print(HST_THREE_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_THREE_FUNCTION_PRIMARY["TARGNAME"])
print(HST_THREE_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_THREE_FUNCTION_PRIMARY["RA_TARG"])
print(HST_THREE_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_THREE_FUNCTION_PRIMARY["DEC_TARG"])

# %% [markdown]
# #### WORLD COORDINATE SYSTEM

# %%
print(HST_THREE_FUNCTION_SCI.comments["LTV1"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["LTV1"])
print(HST_THREE_FUNCTION_SCI.comments["LTV2"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["LTV2"])
print(HST_THREE_FUNCTION_SCI.comments["LTM1_1"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["LTM1_1"])
print(HST_THREE_FUNCTION_SCI.comments["LTM2_2"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["LTM2_2"])
print(HST_THREE_FUNCTION_SCI.comments["RA_APER"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["RA_APER"])
print(HST_THREE_FUNCTION_SCI.comments["DEC_APER"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["DEC_APER"])
print(HST_THREE_FUNCTION_SCI.comments["PA_APER"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["PA_APER"])

# %% [markdown]
# #### EXPOSURE INFORMATION

# %%
print(HST_THREE_FUNCTION_SCI.comments["ORIENTAT"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["ORIENTAT"])
print(HST_THREE_FUNCTION_SCI.comments["SUNANGLE"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["SUNANGLE"])
print(HST_THREE_FUNCTION_SCI.comments["MOONANGL"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["MOONANGL"])
print(HST_THREE_FUNCTION_SCI.comments["SUN_ALT"] + " ","%.10f" % HST_THREE_FUNCTION_SCI["SUN_ALT"])
print(HST_THREE_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_THREE_FUNCTION_SCI["DATE-OBS"])
print(HST_THREE_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_THREE_FUNCTION_SCI["TIME-OBS"])

# %% [markdown]
# #### TARGET ACQUISITION PARAMETERS

# %%
print(HST_THREE_FUNCTION_SCI.comments["TARGA1"] + " ",HST_THREE_FUNCTION_SCI["TARGA1"])
print(HST_THREE_FUNCTION_SCI.comments["TARGA2"] + " ",HST_THREE_FUNCTION_SCI["TARGA2"])
print(HST_THREE_FUNCTION_SCI.comments["APERA1"] + " ",HST_THREE_FUNCTION_SCI["APERA1"])
print(HST_THREE_FUNCTION_SCI.comments["APERA2"] + " ",HST_THREE_FUNCTION_SCI["APERA2"])

# %% [markdown]
# ### HST OPTICAL FOUR

# %% [markdown]
# #### TARGET INFORMATIONS

# %%
print(HST_FOUR_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_FOUR_FUNCTION_PRIMARY["TARGNAME"])
print(HST_FOUR_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_FOUR_FUNCTION_PRIMARY["RA_TARG"])
print(HST_FOUR_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_FOUR_FUNCTION_PRIMARY["DEC_TARG"])

# %% [markdown]
# #### WORLD COORDINATE SYSTEM

# %%
print(HST_FOUR_FUNCTION_SCI.comments["LTV1"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["LTV1"])
print(HST_FOUR_FUNCTION_SCI.comments["LTV2"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["LTV2"])
print(HST_FOUR_FUNCTION_SCI.comments["LTM1_1"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["LTM1_1"])
print(HST_FOUR_FUNCTION_SCI.comments["LTM2_2"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["LTM2_2"])
print(HST_FOUR_FUNCTION_SCI.comments["RA_APER"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["RA_APER"])
print(HST_FOUR_FUNCTION_SCI.comments["DEC_APER"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["DEC_APER"])
print(HST_FOUR_FUNCTION_SCI.comments["PA_APER"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["PA_APER"])

# %% [markdown]
# #### EXPOSURE INFORMATION

# %%
print(HST_FOUR_FUNCTION_SCI.comments["ORIENTAT"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["ORIENTAT"])
print(HST_FOUR_FUNCTION_SCI.comments["SUNANGLE"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["SUNANGLE"])
print(HST_FOUR_FUNCTION_SCI.comments["MOONANGL"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["MOONANGL"])
print(HST_FOUR_FUNCTION_SCI.comments["SUN_ALT"] + " ","%.10f" % HST_FOUR_FUNCTION_SCI["SUN_ALT"])
print(HST_FOUR_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_FOUR_FUNCTION_SCI["DATE-OBS"])
print(HST_FOUR_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_FOUR_FUNCTION_SCI["TIME-OBS"])

# %% [markdown]
# ### ALL OBJECTS

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["TARGNAME"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_ONE_FUNCTION_PRIMARY["TARGNAME"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_TWO_FUNCTION_PRIMARY["TARGNAME"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_THREE_FUNCTION_PRIMARY["TARGNAME"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_PRIMARY.comments["TARGNAME"] + " ",HST_FOUR_FUNCTION_PRIMARY["TARGNAME"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["RA_TARG"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_ONE_FUNCTION_PRIMARY["RA_TARG"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_TWO_FUNCTION_PRIMARY["RA_TARG"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_THREE_FUNCTION_PRIMARY["RA_TARG"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_PRIMARY.comments["RA_TARG"] + " ",HST_FOUR_FUNCTION_PRIMARY["RA_TARG"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["DEC_TARG"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_ONE_FUNCTION_PRIMARY["DEC_TARG"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_TWO_FUNCTION_PRIMARY["DEC_TARG"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_THREE_FUNCTION_PRIMARY["DEC_TARG"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_PRIMARY.comments["DEC_TARG"] + " ",HST_FOUR_FUNCTION_PRIMARY["DEC_TARG"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_PRIMARY.comments["SUNANGLE"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["SUNANGLE"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_SCI.comments["SUNANGLE"] + " ",HST_ONE_FUNCTION_SCI["SUNANGLE"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_SCI.comments["SUNANGLE"] + " ",HST_TWO_FUNCTION_SCI["SUNANGLE"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_SCI.comments["SUNANGLE"] + " ",HST_THREE_FUNCTION_SCI["SUNANGLE"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_SCI.comments["SUNANGLE"] + " ",HST_FOUR_FUNCTION_SCI["SUNANGLE"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_PRIMARY.comments["MOONANGL"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["MOONANGL"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_SCI.comments["MOONANGL"] + " ",HST_ONE_FUNCTION_SCI["MOONANGL"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_SCI.comments["MOONANGL"] + " ",HST_TWO_FUNCTION_SCI["MOONANGL"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_SCI.comments["MOONANGL"] + " ",HST_THREE_FUNCTION_SCI["MOONANGL"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_SCI.comments["MOONANGL"] + " ",HST_FOUR_FUNCTION_SCI["MOONANGL"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_PRIMARY.comments["DATE-OBS"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["DATE-OBS"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_ONE_FUNCTION_SCI["DATE-OBS"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_TWO_FUNCTION_SCI["DATE-OBS"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_THREE_FUNCTION_SCI["DATE-OBS"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_SCI.comments["DATE-OBS"] + " ",HST_FOUR_FUNCTION_SCI["DATE-OBS"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_PRIMARY.comments["TIME-OBS"] + " ",NEAR_INFRARED_FUNCTION_PRIMARY["TIME-OBS"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_ONE_FUNCTION_SCI["TIME-OBS"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_TWO_FUNCTION_SCI["TIME-OBS"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_THREE_FUNCTION_SCI["TIME-OBS"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_SCI.comments["TIME-OBS"] + " ",HST_FOUR_FUNCTION_SCI["TIME-OBS"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_SCI.comments["PA_APER"] + " ",NEAR_INFRARED_FUNCTION_SCI["PA_APER"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_SCI.comments["PA_APER"] + " ",HST_ONE_FUNCTION_SCI["PA_APER"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_SCI.comments["PA_APER"] + " ",HST_TWO_FUNCTION_SCI["PA_APER"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_SCI.comments["PA_APER"] + " ",HST_THREE_FUNCTION_SCI["PA_APER"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_SCI.comments["PA_APER"] + " ",HST_FOUR_FUNCTION_SCI["PA_APER"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_SCI.comments["RA_APER"] + " ",NEAR_INFRARED_FUNCTION_SCI["RA_APER"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_SCI.comments["RA_APER"] + " ",HST_ONE_FUNCTION_SCI["RA_APER"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_SCI.comments["RA_APER"] + " ",HST_TWO_FUNCTION_SCI["RA_APER"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_SCI.comments["RA_APER"] + " ",HST_THREE_FUNCTION_SCI["RA_APER"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_SCI.comments["RA_APER"] + " ",HST_FOUR_FUNCTION_SCI["RA_APER"])

# %%
print("NEAR INFRARED'S  " + NEAR_INFRARED_FUNCTION_SCI.comments["DEC_APER"] + " ",NEAR_INFRARED_FUNCTION_SCI["DEC_APER"])
print("HST OPTICAL ONE'S  " + HST_ONE_FUNCTION_SCI.comments["DEC_APER"] + " ",HST_ONE_FUNCTION_SCI["DEC_APER"])
print("HST OPTICAL TWO'S  " + HST_TWO_FUNCTION_SCI.comments["DEC_APER"] + " ",HST_TWO_FUNCTION_SCI["DEC_APER"])
print("HST OPTICAL THREE'S  " + HST_THREE_FUNCTION_SCI.comments["DEC_APER"] + " ",HST_THREE_FUNCTION_SCI["DEC_APER"])
print("HST OPTICAL FOUR'S " + HST_FOUR_FUNCTION_SCI.comments["DEC_APER"] + " ",HST_FOUR_FUNCTION_SCI["DEC_APER"])

# %% [markdown]
# # SPECTRAL TYPE ANALYSIS AND OBSERVING IMAGE

# %%
CMAP_LIST = ["gray","jet","hot","prism","nipy_spectral",
             "gist_ncar","gist_earth","gist_stern","flag","gnuplot2","afmhot",
            "bwr",'PiYG','PRGn','BrBG','PuOr','RdGy','RdBu','terrain']

# %% [markdown]
# ### GETTING IMAGE DATA

# %% [markdown]
# #### NEAR INFRARED

# %%
NI_SCI = OPEN_NI[1].data
NI_WHT = OPEN_NI[2].data
NI_CTX = OPEN_NI[3].data

# %%
NI_SCI = NI_SCI.astype(np.uint8)
NI_WHT = NI_WHT.astype(np.uint8)
NI_CTX = NI_CTX.astype(np.uint8)

# %% [markdown]
# #### HST OPTICAL ONE

# %%
HST_ONE_SCI_1 = OPEN_HST_ONE[1].data
HST_ONE_SCI_2 = OPEN_HST_ONE[4].data
HST_ONE_SCI_3 = OPEN_HST_ONE[7].data

# %%
HST_ONE_SCI_1 = HST_ONE_SCI_1.astype(np.uint8)
HST_ONE_SCI_2 = HST_ONE_SCI_2.astype(np.uint8)
HST_ONE_SCI_3 = HST_ONE_SCI_3.astype(np.uint8)

# %% [markdown]
# #### HST OPTICAL TWO

# %%
HST_TWO_SCI = OPEN_HST_TWO[1].data
HST_TWO_PEAK = OPEN_HST_TWO[4].data

# %%
HST_TWO_SCI = HST_TWO_SCI.astype(np.uint8)

# %% [markdown]
# #### HST OPTICAL THREE

# %%
HST_THREE_SCI_1 = OPEN_HST_THREE[1].data
HST_THREE_SCI_2 = OPEN_HST_THREE[4].data
HST_THREE_SCI_3 = OPEN_HST_THREE[7].data

# %%
HST_THREE_SCI_1 = HST_THREE_SCI_1.astype(np.uint8)
HST_THREE_SCI_2 = HST_THREE_SCI_2.astype(np.uint8)
HST_THREE_SCI_3 = HST_THREE_SCI_3.astype(np.uint8)

# %% [markdown]
# #### HST OPTICAL FOUR

# %%
HST_FOUR_SCI = OPEN_HST_FOUR[1].data
HST_FOUR_PEAK = OPEN_HST_FOUR[4].data

# %%
HST_FOUR_SCI = HST_FOUR_SCI.astype(np.uint8)

# %% [markdown]
# ### OBSERVING

# %% [markdown]
# ### ATTENTION
# * RUN FOR CHECKING
# * THEY ARE RAW

# %% [markdown]
# #### NEAR INFRARED

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(NI_SCI,cmap=x_spec)
    axis[0].set_title("NEAR INFRARE SCI" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(NI_WHT,cmap=x_spec)
    axis[1].set_title("NEAR INFRARED WHT" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(NI_CTX,cmap=x_spec)
    axis[2].set_title("NEAR INFRARED CTX" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### HST OPTICAL ONE

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(HST_ONE_SCI_1,cmap=x_spec)
    axis[0].set_title("HST SCI 1" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(HST_ONE_SCI_2,cmap=x_spec)
    axis[1].set_title("HST SCI 2" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(HST_ONE_SCI_3,cmap=x_spec)
    axis[2].set_title("HST SCI 3" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### HST OPTICAL TWO

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,2,figsize=(20,20))
    
    axis[0].imshow(HST_TWO_SCI,cmap=x_spec)
    axis[0].set_title("HST SCI" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(HST_TWO_PEAK,cmap=x_spec)
    axis[1].set_title("HST PEAK" + " / "+ x_spec)
    axis[1].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### HST OPTICAL THREE

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(HST_THREE_SCI_1,cmap=x_spec)
    axis[0].set_title("HST SCI 1" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(HST_THREE_SCI_2,cmap=x_spec)
    axis[1].set_title("HST SCI 2" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(HST_THREE_SCI_3,cmap=x_spec)
    axis[2].set_title("HST SCI 3" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### HST OPTICAL FOUR

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,2,figsize=(20,20))
    
    axis[0].imshow(HST_FOUR_SCI,cmap=x_spec)
    axis[0].set_title("HST SCI" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(HST_FOUR_PEAK,cmap=x_spec)
    axis[1].set_title("HST PEAK" + " / "+ x_spec)
    axis[1].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### OBSERVATION IMAGE DETAIL

# %% [markdown]
# #### TRANSFORMATION

# %%
NI_SCI_WIDE_RANGE = NI_SCI[110:145,120:175]
NI_SCI_MASS = NI_SCI[110:185,120:175]
HST_ONE_SCI_2_WIDE_RANGE = HST_ONE_SCI_2[20:75,20:75]
HST_THREE_SCI_2_WIDE_RANGE = HST_THREE_SCI_2[20:75,20:75]

# %%
OBSERVATION_IMAGE_LIST = [NI_SCI,NI_SCI_MASS,NI_SCI_WIDE_RANGE,HST_ONE_SCI_2,HST_ONE_SCI_2_WIDE_RANGE,HST_THREE_SCI_2,HST_THREE_SCI_2_WIDE_RANGE,HST_TWO_SCI]

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(NI_SCI_WIDE_RANGE,cmap=x_spec)
    axis[0].set_title("NEAR INFRARED WIDE SCALE" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(HST_ONE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[1].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(HST_THREE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[2].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### SATO

# %%
SATO_NI_SCI_WIDE_RANGE = filters.sato(NI_SCI_WIDE_RANGE)
SATO_NI_SCI_MASS = filters.sato(NI_SCI_MASS)
SATO_HST_ONE_SCI_2_WIDE_RANGE = filters.sato(HST_ONE_SCI_2_WIDE_RANGE)
SATO_HST_THREE_SCI_2_WIDE_RANGE = filters.sato(HST_THREE_SCI_2_WIDE_RANGE)

# %%
SATO_NI = filters.sato(NI_SCI)
SATO_HST_ONE = filters.sato(HST_ONE_SCI_2)
SATO_HST_THREE = filters.sato(HST_THREE_SCI_2)

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,4,figsize=(20,20))
    
    DENSITY_FUNC = axis[0].imshow(SATO_NI_SCI_WIDE_RANGE,cmap=x_spec)
    axis[0].set_title("NEAR INFRARED WIDE SCALE" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(SATO_NI_SCI_MASS,cmap=x_spec)
    axis[1].set_title("NEAR INFRARED MASS" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(SATO_HST_ONE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[2].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[2].axis("off")
    
    axis[3].imshow(SATO_HST_THREE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[3].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[3].axis("off")
    
    figure.colorbar(DENSITY_FUNC,shrink=0.3,label="DENSITY",location="right",extend="max")
    plt.tight_layout()
    plt.show()

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(SATO_NI,cmap=x_spec)
    axis[0].set_title("NEAR INFRARED" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(SATO_HST_ONE,cmap=x_spec)
    axis[1].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(SATO_HST_THREE,cmap=x_spec)
    axis[2].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### NEGATIVE DIAGRAM

# %%
NEG_DIA_NI_SCI_WIDE_RANGE = filters.roberts_neg_diag(NI_SCI_WIDE_RANGE)
NEG_DIA_NI_SCI_MASS = filters.roberts_neg_diag(NI_SCI_MASS)
NEG_DIA_HST_ONE_SCI_2_WIDE_RANGE = filters.roberts_neg_diag(HST_ONE_SCI_2_WIDE_RANGE)
NEG_DIA_HST_THREE_SCI_2_WIDE_RANGE = filters.roberts_neg_diag(HST_THREE_SCI_2_WIDE_RANGE)

# %%
NEG_DIA_NI = filters.roberts_neg_diag(NI_SCI)
NEG_DIA_HST_ONE = filters.roberts_neg_diag(HST_ONE_SCI_2)
NEG_DIA_HST_THREE = filters.roberts_neg_diag(HST_THREE_SCI_2)

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,4,figsize=(20,20))
    
    DENSITY_FUNC = axis[0].imshow(NEG_DIA_NI_SCI_WIDE_RANGE,cmap=x_spec)
    axis[0].set_title("NEAR INFRARED WIDE SCALE" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(NEG_DIA_NI_SCI_MASS,cmap=x_spec)
    axis[1].set_title("NEAR INFRARED MASS" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(NEG_DIA_HST_ONE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[2].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[2].axis("off")
    
    axis[3].imshow(NEG_DIA_HST_THREE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[3].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[3].axis("off")
    
    figure.colorbar(DENSITY_FUNC,shrink=0.3,label="DENSITY",location="right",extend="max")
    plt.tight_layout()
    plt.show()

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(NEG_DIA_NI,cmap=x_spec)
    axis[0].set_title("NEAR INFRARED" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(NEG_DIA_HST_ONE,cmap=x_spec)
    axis[1].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(NEG_DIA_HST_THREE,cmap=x_spec)
    axis[2].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### MEIJERING

# %%
MEI_NI_SCI_WIDE_RANGE = filters.meijering(NI_SCI_WIDE_RANGE,black_ridges=False)
MEI_NI_SCI_MASS = filters.meijering(NI_SCI_MASS,black_ridges=False)
MEI_HST_ONE_SCI_2_WIDE_RANGE = filters.meijering(HST_ONE_SCI_2_WIDE_RANGE,black_ridges=False)
MEI_HST_THREE_SCI_2_WIDE_RANGE = filters.meijering(HST_THREE_SCI_2_WIDE_RANGE,black_ridges=False)

# %%
MEI_NI = filters.meijering(NI_SCI,black_ridges=False)
MEI_HST_ONE = filters.meijering(HST_ONE_SCI_2,black_ridges=False)
MEI_HST_THREE = filters.meijering(HST_THREE_SCI_2,black_ridges=False)

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,4,figsize=(20,20))
    
    DENSITY_FUNC = axis[0].imshow(MEI_NI_SCI_WIDE_RANGE,cmap=x_spec)
    axis[0].set_title("NEAR INFRARED WIDE SCALE" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(MEI_NI_SCI_MASS,cmap=x_spec)
    axis[1].set_title("NEAR INFRARED MASS" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(MEI_HST_ONE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[2].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[2].axis("off")
    
    axis[3].imshow(MEI_HST_THREE_SCI_2_WIDE_RANGE,cmap=x_spec)
    axis[3].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[3].axis("off")
    
    figure.colorbar(DENSITY_FUNC,shrink=0.3,label="DENSITY",location="right",extend="max")
    plt.tight_layout()
    plt.show()

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(MEI_NI,cmap=x_spec)
    axis[0].set_title("NEAR INFRARED" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(MEI_HST_ONE,cmap=x_spec)
    axis[1].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(MEI_HST_THREE,cmap=x_spec)
    axis[2].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### CORNER MASS

# %%
FCF_NI_SCI_WIDE_RANGE = skimage.feature.corner_foerstner(NI_SCI_WIDE_RANGE,sigma=5)
FCF_NI_SCI_MASS = skimage.feature.corner_foerstner(NI_SCI_MASS,sigma=5)
FCF_HST_ONE_SCI_2_WIDE_RANGE = skimage.feature.corner_foerstner(HST_ONE_SCI_2_WIDE_RANGE,sigma=5)
FCF_HST_THREE_SCI_2_WIDE_RANGE = skimage.feature.corner_foerstner(HST_THREE_SCI_2_WIDE_RANGE,sigma=5)

# %%
FCF_NI = skimage.feature.corner_foerstner(NI_SCI,sigma=5)
FCF_HST_ONE = skimage.feature.corner_foerstner(HST_ONE_SCI_2,sigma=5)
FCF_HST_THREE = skimage.feature.corner_foerstner(HST_THREE_SCI_2,sigma=5)

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,4,figsize=(20,20))
    
    DENSITY_FUNC = axis[0].imshow(FCF_NI_SCI_WIDE_RANGE[1],cmap=x_spec)
    axis[0].set_title("NEAR INFRARED WIDE SCALE" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(FCF_NI_SCI_MASS[1],cmap=x_spec)
    axis[1].set_title("NEAR INFRARED MASS" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(FCF_HST_ONE_SCI_2_WIDE_RANGE[1],cmap=x_spec)
    axis[2].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[2].axis("off")
    
    axis[3].imshow(FCF_HST_THREE_SCI_2_WIDE_RANGE[1],cmap=x_spec)
    axis[3].set_title("HST OPTICAL SCI WIDE SCALE" + " / "+ x_spec)
    axis[3].axis("off")
    
    figure.colorbar(DENSITY_FUNC,shrink=0.3,label="DENSITY",location="right",extend="max")
    plt.tight_layout()
    plt.show()

# %%
for x_spec in CMAP_LIST:
    
    figure,axis = plt.subplots(1,3,figsize=(20,20))
    
    axis[0].imshow(FCF_NI[1],cmap=x_spec)
    axis[0].set_title("NEAR INFRARED" + " / "+ x_spec)
    axis[0].axis("off")
    
    axis[1].imshow(FCF_HST_ONE[1],cmap=x_spec)
    axis[1].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[1].axis("off")
    
    axis[2].imshow(FCF_HST_THREE[1],cmap=x_spec)
    axis[2].set_title("HST OPTICAL" + " / "+ x_spec)
    axis[2].axis("off")
    
    plt.tight_layout()
    plt.show()

# %%
NI_SCI_WIDE_RANGE_FLATTEN = NI_SCI_WIDE_RANGE.flatten()

# %%
figure,axis = plt.subplots(1,2,figsize=(22,7))
    
DENSITY_FUNC = axis[0].imshow(NI_SCI_WIDE_RANGE,cmap="hot")
axis[0].set_title("NEAR INFRARED")
axis[0].axis("off")
    
axis[1].plot(NI_SCI_WIDE_RANGE_FLATTEN,color="red")
axis[1].set_title("PLOT")
axis[1].axis("off")

figure.colorbar(DENSITY_FUNC,shrink=0.5,label="DENSITY",location="right",extend="both")
plt.tight_layout()
plt.show()

# %%
FCF_NI_FLATTEN = FCF_NI_SCI_WIDE_RANGE[1].flatten()

# %%
figure,axis = plt.subplots(1,2,figsize=(22,7))
    
DENSITY_FUNC = axis[0].imshow(FCF_NI_SCI_WIDE_RANGE[1],cmap="flag")
axis[0].set_title("NEAR INFRARED")
axis[0].axis("off")
    
axis[1].plot(FCF_NI_FLATTEN,color="black")
axis[1].set_title("PLOT FCF")
axis[1].axis("off")

figure.colorbar(DENSITY_FUNC,shrink=0.5,label="DENSITY",location="right",extend="both")
plt.tight_layout()
plt.show()

# %%
MEI_MASS_FLATTEN = MEI_NI_SCI_MASS.flatten()

# %%
figure,axis = plt.subplots(1,2,figsize=(22,7))
    
DENSITY_FUNC = axis[0].imshow(MEI_NI_SCI_MASS,cmap="flag")
axis[0].set_title("NEAR INFRARED MASS")
axis[0].axis("off")
    
axis[1].plot(MEI_MASS_FLATTEN,color="black")
axis[1].set_title("PLOT MASS")
axis[1].axis("off")

figure.colorbar(DENSITY_FUNC,shrink=0.5,label="DENSITY",location="right",extend="both")
plt.tight_layout()
plt.show()

# %%
GENERAL_NI_FLATTEN = NI_SCI.flatten()

# %%
figure,axis = plt.subplots(1,2,figsize=(22,7))
    
DENSITY_FUNC = axis[0].imshow(NI_SCI,cmap="flag")
axis[0].set_title("NEAR INFRARED GENERAL")
axis[0].axis("off")
    
axis[1].plot(GENERAL_NI_FLATTEN,color="black")
axis[1].set_title("PLOT GENERAL")
axis[1].axis("off")

figure.colorbar(DENSITY_FUNC,shrink=0.5,label="DENSITY",location="right",extend="both")
plt.tight_layout()
plt.show()
